# %% [markdown]
# Text Type:	str
#
# Numeric Types:	int, float, complex
#
# Sequence Types:	list, tuple, range
#
# Mapping Type:	dict
#
# Set Types:	set, frozenset
#
# Boolean Type:	bool
#
# Binary Types:	bytes, bytearray, memoryview
#
# None Type:	NoneType

# %%
# 1 ->> Data type (integer)

a = 50
b= 00000
c = 45479123588966


print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # 2 String

# %%
a = 'A'
b = " This is a String "

print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# # 3 Float   ( Remember Always a Point .)

# %%
x = 1.00

y = 2548789.222

z = 9.000000000000000006466446600000

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# # 4 Complex

# %%
a = 1j

b = 99 +1j

print(type(a))
print(type(b))
# Out:
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# # 5 List  [ List ]

# %%
L = ["jaipur", "Agra", "Delhi", " Goa"]

print(L)

print(type(L))
# Out:
# ['jaipur', 'Agra', 'Delhi', ' Goa']
# <class 'list'>

# %% [markdown]
# # 6  Tuple   (tuple)

# %%
T = ("rahul", "muskan", "Ajay","Naseem")

print(T)
print(type(T))
# Out:
# ('rahul', 'muskan', 'Ajay', 'Naseem')
# <class 'tuple'>

# %% [markdown]
# # 7  Set {Set}

# %%
d = {"Apple", "Bnana", " Orange", "Cherry"}

print(d)

print(type(d))
# Out:
# {'Cherry', ' Orange', 'Apple', 'Bnana'}
# <class 'set'>

# %% [markdown]
# # 8 Dictionary  {A : B}

# %%
a  = {"rahul" : 20, "Shaleen" : 23, " Pooja": 22}

print(a)

print(type(a))
# Out:
# {'rahul': 20, 'Shaleen': 23, ' Pooja': 22}
# <class 'dict'>

# %% [markdown]
# # 9 Bool     True  or False

# %%
a = True

b = False

print(type(a))
print(type(b))


x = 5
y=7

print(x > y)
# Out:
# <class 'bool'>
# <class 'bool'>
# False

# %% [markdown]
# # 10 range    Given Range 0 to n

# %%
a = range(6)
print(a)


print(type(a))
# Out:
# range(0, 6)
# <class 'range'>

# %% [markdown]
# # Note---->
#
# int, float , complex are numeric type
