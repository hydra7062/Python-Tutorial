# %% [markdown]
# # Python Assignment Operators
#
# * =
# * +=
# * -=
# * *=
# * /=
# * %=
# * &=
# * <<=
# * (>>=)

# %%
x = 5
a= 10
print(x)



x1 = 50
x2 = 50
x3 = 50
x4 = 50

x1 += 10
x2 -= 10
x3 *= 10
x4 /= 10
print(x1)
print(x2)
print(x3)
print(x4)
# Out:
# 5
# 60
# 40
# 500
# 5.0

# %%
b = 5
b >>= 5
print(b)
# Out:
# 0

# %%
Do Practice With other operators!!!
