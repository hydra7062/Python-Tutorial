# %% [markdown]
# # Comparison Operators
#
# * Equal                         ==
# * Not Equal                     !=
# *	Greater than                  >
# * Less than                     <
# * Greater than or equal to      >=
# * Less than or equal to         <=

# %%
a = 5
b = 6

c = a== b
print(c)


print(7==7)

print(10!=10)


if a >= b:
  print(" a is greater than qual to the b")

else:
  print("a is NOT greater than qual to the b")
# Out:
# False
# True
# False
# a is NOT greater than qual to the b

# %%
DO YOURSELF OTHER OPERATORS
