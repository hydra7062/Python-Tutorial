# %%
print(" Hello My Friends!!")
# Out:
#  Hello My Friends!!

# %%
if 50  > 10:
  print(" 50 Greater than 10 ")
# Out:
#  50 Greater than 10

# %% [markdown]
# # Pytho Comments
#
# using Hash #
#
# Like -->   # Print ("Hello World" )

# %%
 # Print ("Hello World" )
